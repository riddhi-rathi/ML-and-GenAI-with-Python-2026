# %% [markdown]
# # Assignment 2 Solutions
#
# **Student Name:** Riddhi Rathi
# **Enrollment Number:** 17001012024
# **College Name:** IGDTUW

# %% [markdown]
# ## Sum of First 10 Natural Numbers

# %%
# Simple solution for the given problem
sum_n = 0
for i in range(1, 11):
    sum_n += i
print("Sum =", sum_n)
# Out:
# Sum = 55

# %% [markdown]
# ## Factorial of a Number

# %%
n = int(input("Enter a number: "))
fact = 1
for i in range(1, n + 1):
    fact *= i
print("Factorial =", fact)
# Out:
# Enter a number: 5
# Factorial = 120

# %% [markdown]
# ## Fibonacci Series

# %%
n = int(input("How many terms? "))
a, b = 0, 1
for i in range(n):
    print(a, end=" ")
    a, b = b, a + b
# Out:
# How many terms? 8
# 0 1 1 2 3 5 8 13

# %% [markdown]
# ## Largest Among 3 Numbers

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))

if a >= b and a >= c:
    print("Largest =", a)
elif b >= a and b >= c:
    print("Largest =", b)
else:
    print("Largest =", c)
# Out:
# Enter first number: 27
# Enter second number: 89
# Enter third number: 94
# Largest = 94.0

# %% [markdown]
# ## Student Result System

# %%
# Student Result System

name = input("Enter Student Name: ")
roll = input("Enter Roll Number: ")

subjects = 5
total = 0

for i in range(1, subjects + 1):
    marks = float(input(f"Enter marks of Subject {i}: "))
    total += marks

percentage = total / subjects

if percentage >= 90:
    grade = "A+"
elif percentage >= 80:
    grade = "A"
elif percentage >= 70:
    grade = "B"
elif percentage >= 60:
    grade = "C"
elif percentage >= 50:
    grade = "D"
else:
    grade = "F"

print("\n----- Student Result -----")
print("Name:", name)
print("Enrollment No:", roll)
print("Total Marks:", total)
print("Percentage:", percentage)
print("Grade:", grade)
# Out:
# Enter Student Name: Riddhi Rtahi
# Enter Roll Number: 17001012024
# Enter marks of Subject 1: 84
# Enter marks of Subject 2: 93
# Enter marks of Subject 3: 97
# Enter marks of Subject 4: 89
# Enter marks of Subject 5: 87
#
# ----- Student Result -----
# Name: Riddhi Rtahi
# Enrollment No: 17001012024
# Total Marks: 450.0
# Percentage: 90.0
# Grade: A+
